# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def eda_report(df):

    print('='*60)
    print('DATASET SHAPE')
    print(df.shape)

    print('\n'+'='*60)
    print('DUPLICATES')
    print(df.duplicated().sum())
    
    print('\n' + '='*60)
    print('DATA TYPES')
    display(df.dtypes)

    print('\n' + '='*60)
    print('UNIQUE VALUES')
    display(df.nunique())

    
    print('\n'+'='*60)
    print('MISSING VALUES')
    display(
        pd.DataFrame({
            'Null Count':df.isnull().sum(),
            'Null %':round(df.isnull().mean()*100,2)
        }).sort_values('Null %',ascending=False)
    )

    print('\n'+'='*60)
    print('NUMERICAL SUMMARY')
    display(df.describe())

    print('\n'+'='*60)
    print('CATEGORICAL SUMMARY')
    display(df.describe(include='object'))

# %%
eda_report(df)
# Out:
# ...
# DATASET SHAPE
# (891, 12)
#
# ...
# DUPLICATES
# 0
#
# ...
# DATA TYPES
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# ...
# UNIQUE VALUES
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64
# ...
# MISSING VALUES
#              Null Count  Null %
# Cabin               687   77.10
# Age                 177   19.87
# Embarked              2    0.22
# PassengerId           0    0.00
# Survived              0    0.00
# Pclass                0    0.00
# Name                  0    0.00
# Sex                   0    0.00
# ...

# %%
test=pd.read_csv("test.csv")

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
def eda_report(test):

    print('='*60)
    print('DATASET SHAPE')
    print(test.shape)

    print('\n'+'='*60)
    print('DUPLICATES')
    print(test.duplicated().sum())
    
    print('\n' + '='*60)
    print('DATA TYPES')
    display(test.dtypes)

    print('\n' + '='*60)
    print('UNIQUE VALUES')
    display(test.nunique())


    print('\n'+'='*60)
    print('MISSING VALUES')
    display(
        pd.DataFrame({
            'Null Count':test.isnull().sum(),
            'Null %':round(test.isnull().mean()*100,2)
        }).sort_values('Null %',ascending=False)
    )

    print('\n'+'='*60)
    print('NUMERICAL SUMMARY')
    display(test.describe())

    print('\n'+'='*60)
    print('CATEGORICAL SUMMARY')
    display(test.describe(include='object'))

# %%
eda_report(test)
# Out:
# ...
# DATASET SHAPE
# (418, 11)
#
# ...
# DUPLICATES
# 0
#
# ...
# DATA TYPES
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# ...
# UNIQUE VALUES
# PassengerId    418
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64
# ...
# MISSING VALUES
#              Null Count  Null %
# Cabin               327   78.23
# Age                  86   20.57
# Fare                  1    0.24
# PassengerId           0    0.00
# Pclass                0    0.00
# Name                  0    0.00
# Sex                   0    0.00
# SibSp                 0    0.00
# Parch                 0    0.00
# ...

# %% [markdown]
# # Feature Engineering

# %%
#joins the tow tables and doing Feature Engineering
# adding new required columns

# %%
train_test = pd.concat([df, test], ignore_index=True)

# %%
train_test
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
train_test['Survived'].value_counts()
# Out:
# 0.0    549
# 1.0    342
# Name: Survived, dtype: int64

# %%
train_test.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived       31.932773
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.091673
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.076394
# Cabin          77.463713
# Embarked        0.152788
# dtype: float64

# %%
train_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
train_test['FamilySize'] = train_test['SibSp'] + train_test['Parch'] + 1

# %%
train_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           2
# 1      0          PC 17599  71.2833   C85        C           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1
# ...

# %%
train_test['FamilyType'] = np.where(train_test['FamilySize'] == 1, 'Alone',
                           np.where(train_test['FamilySize'] == 2, 'Double',
                           np.where(train_test['FamilySize'] < 5,'Small',
                           'Large')))

# %%
train_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize FamilyType
# 0      0         A/5 21171   7.2500   NaN        S           2     Double
# 1      0          PC 17599  71.2833   C85        C           2     Double
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1      Alone
# ...

# %%
train_test['FamilyType'].value_counts()
# Out:
# Alone     790
# Double    235
# Small     202
# Large      82
# Name: FamilyType, dtype: int64

# %%
train_test.loc[train_test['FamilyType'] == 'Small','FamilySize'].value_counts()
# Out:
# 3    159
# 4     43
# Name: FamilySize, dtype: int64

# %%
train_test.loc[train_test['FamilyType'] == 'Double','FamilySize'].value_counts()
# Out:
# 2    235
# Name: FamilySize, dtype: int64

# %%
train_test.loc[train_test['FamilyType'] == 'Large','FamilySize'].value_counts()
# Out:
# 6     25
# 5     22
# 7     16
# 11    11
# 8      8
# Name: FamilySize, dtype: int64

# %%
train_test['FarePerPerson'] = train_test['Fare'] / train_test['FamilySize']

# %%
train_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize FamilyType  \
# 0      0         A/5 21171   7.2500   NaN        S           2     Double
# 1      0          PC 17599  71.2833   C85        C           2     Double
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1      Alone
# ...

# %%
train_test['NameTitle'] = train_test['Name'].str.extract(' ([A-Za-z]+)\.')

# %%
train_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize FamilyType  \
# 0      0         A/5 21171   7.2500   NaN        S           2     Double
# 1      0          PC 17599  71.2833   C85        C           2     Double
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1      Alone
# ...

# %%
bins=[0,2,12,19,30,60,100]
labels= ['Infants','Children','Teens','Young Adults','Adults','seniors']
train_test['Age_Group']=pd.cut(train_test['Age'],bins=bins,labels=labels,right=True)
train_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize FamilyType  \
# 0      0         A/5 21171   7.2500   NaN        S           2     Double
# 1      0          PC 17599  71.2833   C85        C           2     Double
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1      Alone
# ...

# %%
train_test['TicketGroupSize'] = train_test.groupby('Ticket')['Ticket'].transform('count')

# %%
train_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize FamilyType  \
# 0      0         A/5 21171   7.2500   NaN        S           2     Double
# 1      0          PC 17599  71.2833   C85        C           2     Double
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1      Alone
# ...

# %%
train_test['NameTitle'].value_counts()
# Out:
# Mr          757
# Miss        260
# Mrs         197
# Master       61
# Rev           8
# Dr            8
# Col           4
# Mlle          2
# Major         2
# Ms            2
# Lady          1
# Sir           1
# Mme           1
# Don           1
# Capt          1
# Countess      1
# Jonkheer      1
# Dona          1
# Name: NameTitle, dtype: int64

# %%
train_test['Surname'] = train_test['Name'].str.split(',').str[0]

# %%
train_test
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# Perform univeriant,bivarient and multivariant on new columns in train test dataset

# %%
## Univariate Analysis
sns.countplot(x="FamilySize",data=train_test)
plt.title("Family Size Distribution")
plt.show()

# %%
# Family Size Distribution
#Most passengers were traveling alone or with very small families.
#Large families were comparatively rare on the Titanic.
#The dataset is highly concentrated around family sizes 1–4.

# %%
sns.countplot(x='Survived', data=train_test)
print(train_test['Survived'].value_counts())
# Out:
# 0.0    549
# 1.0    342
# Name: Survived, dtype: int64

# %%
# Survival Distribution
#The number of passengers who did not survive was higher than those who survived.
#This indicates that the overall survival rate on the Titanic was relatively low.

# %%
sns.countplot(data=train_test, x="Age_Group")
plt.title("Age Group Distribution")
plt.show()

# %%
# Age Group Distribution
#Adults and young adults formed the majority of passengers.
#Very few passengers belonged to infant or senior age groups.
#The passenger population was mostly working-age individuals.

# %%
train_test["FamilyType"].value_counts().plot(kind="pie",autopct="%1.1f%%")
plt.title("Family Type Percentage")
plt.ylabel("")
plt.show()

# %%
# Family Type Percentage
#Most passengers traveled alone or in small families.
#Large family groups made up only a small portion of the dataset.
#Family structure may have influenced survival chances.

# %%
sns.countplot(x=df['Pclass'])
print((df['Pclass'].value_counts()/891)*100)
# Out:
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: Pclass, dtype: float64

# %%
# Passenger Class Distribution (Pclass)
#Most passengers belonged to 3rd class.
#1st class passengers were the smallest group.
#The Titanic mainly carried lower-class passengers.

# %%
sns.countplot(x='Embarked', data=train_test)
plt.title('Embarked Port Distribution')
plt.show()

# %%
# Embarked Port Distribution
#Most passengers boarded from Southampton (S).
#Cherbourg (C) and Queenstown (Q) had fewer passengers.
#Southampton was the primary boarding point.

# %%
sns.countplot(x='Sex', data=train_test)
print(df['Sex'].value_counts())
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# Gender Distribution
#Male passengers were significantly higher in number than female passengers.
#The dataset is male-dominated.

# %%
# Bivariate Analysis
pd.crosstab(train_test['Pclass'], train_test['Survived'])
sns.countplot(x='Pclass', hue='Survived', data=train_test)
plt.title('Survival by Passenger Class')
plt.show()

# %%
# Survival by Passenger Class
#1st class passengers had the highest survival rate.
#3rd class passengers had the lowest survival rate.
#Passenger class strongly influenced survival probability.

# %%
pd.crosstab(train_test['Sex'], train_test['Survived'])

sns.countplot(x='Sex', hue='Survived', data=train_test)
plt.title('Survival by Gender')
plt.show()

# %%
# Survival by Gender
#Females had a much higher survival rate compared to males.
#Most male passengers did not survive.
#Gender was one of the strongest survival factors.

# %%
pd.crosstab(train_test['FamilySize'], train_test['Survived'])
sns.countplot(x='FamilySize', hue='Survived', data=train_test)
plt.title('Family Size vs Survival')
plt.show()

# %%
# Family Size vs Survival
#Passengers traveling in small or medium-sized families had better survival chances.
#Very large families showed lower survival rates.
#Traveling completely alone also reduced survival probability.

# %%
pd.crosstab(train_test['FamilyType'], train_test['Survived'])

sns.countplot(x='FamilyType', hue='Survived', data=train_test)
plt.title('Family Type vs Survival')
plt.show()

# %%
# Family Type vs Survival
#Small families had the best survival outcomes.
#Large families struggled more during evacuation.
#Family grouping clearly impacted survival behavior.

# %%
pd.crosstab(train_test['Age_Group'],train_test['Survived']).plot(kind='bar',stacked=True)
plt.title('Age Group vs Survival')
plt.ylabel('Count')
plt.show()

# %%
# Age Group vs Survival
#Children had relatively better survival rates.
#Adults and seniors experienced lower survival rates.
#This supports the “women and children first” evacuation policy.

# %%
sns.countplot(x="Embarked",hue="Survived",data=train_test)
plt.title("Embarked Survival Rate")
plt.show()

# %%
# Embarked Port vs Survival
#Passengers boarding from Cherbourg (C) had comparatively better survival rates.
#Southampton passengers had lower survival percentages.
#Embarkation location may indirectly reflect passenger class and wealth.

# %%
# multivariate analysis

# %%
sns.catplot(x='Pclass',hue='Survived',col='Sex',data=train_test,kind='count')
plt.show()

# %%
# Passenger Class vs Survival by Gender
#Females across all classes survived more frequently than males.
#1st class females had the highest survival rate overall.
#3rd class males had the poorest survival outcomes.

# %%
sns.catplot(x='Sex',hue='Survived',col='Age_Group',kind='count',data=train_test)

# %%
# Gender vs Survival by Age Group
#Female passengers consistently showed higher survival across almost all age groups.
#Male survival remained lower regardless of age category.
#Children had relatively balanced survival compared to adults.

# %%
sns.catplot(x='Age_Group',hue='Survived',col='Pclass',data=train_test,kind='count',height=5)
plt.show()

# %%
# Age Group vs Survival by Passenger Class
#Younger passengers in higher classes had better survival chances.
#3rd class adults experienced the lowest survival rates.
#Both age and socioeconomic status influenced survival

# %%
sns.catplot(x='Embarked',hue='Survived',col='Pclass',data=train_test,kind='count')
plt.show()

# %%
# Embarked Port vs Survival by Passenger Class
#Survival differences between embarkation ports were strongly connected to passenger class.
#Many Cherbourg passengers belonged to higher classes, improving survival rates.
#Southampton had more 3rd class passengers, leading to lower survival.

# %%
sns.catplot(x='FamilyType',hue='Survived',col='Sex',data=train_test,kind='count',height=5)
plt.show()

# %%
# Family Type vs Survival by Gender
#Female passengers in all family types survived more frequently.
#Males in large families showed poor survival rates.
#Gender remained a dominant survival factor even within family categories.

# %%
sns.catplot(x='FamilyType',hue='Survived',col='Pclass',data=train_test,kind='count',height=5)
plt.show()

# %%
# Family Type vs Survival by Passenger Class
#Small families in 1st and 2nd class had better survival outcomes.
#Large families in 3rd class struggled the most.
#Economic status and family size together affected survival chances.

# %% [markdown]
# # DATA CLEANING

# %%
train_test.isnull().mean()*100
# Out:
# PassengerId         0.000000
# Survived           31.932773
# Pclass              0.000000
# Name                0.000000
# Sex                 0.000000
# Age                20.091673
# SibSp               0.000000
# Parch               0.000000
# Ticket              0.000000
# Fare                0.076394
# Cabin              77.463713
# Embarked            0.152788
# FamilySize          0.000000
# FamilyType          0.000000
# FarePerPerson       0.076394
# NameTitle           0.000000
# Age_Group          20.091673
# TicketGroupSize     0.000000
# Surname             0.000000
# dtype: float64

# %%
eda_report(train_test)
# Out:
# ...
# DATASET SHAPE
# (1309, 19)
#
# ...
# DUPLICATES
# 0
#
# ...
# DATA TYPES
# PassengerId           int64
# Survived            float64
# Pclass                int64
# Name                 object
# Sex                  object
# Age                 float64
# SibSp                 int64
# Parch                 int64
# Ticket               object
# Fare                float64
# Cabin                object
# Embarked             object
# FamilySize            int64
# FamilyType           object
# FarePerPerson       float64
# NameTitle            object
# Age_Group          category
# TicketGroupSize       int64
# Surname              object
# dtype: object
# ...
# UNIQUE VALUES
# PassengerId        1309
# Survived              2
# Pclass                3
# Name               1307
# Sex                   2
# Age                  98
# SibSp                 7
# Parch                 8
# Ticket              929
# Fare                281
# Cabin               186
# Embarked              3
# ...

# %%
def compare_age_fill_visualization(train_test):

    # Original variance
    original_var = train_test['Age'].var()

    # Mean Fill
    mean_age = train_test['Age'].fillna(train_test['Age'].mean())
    mean_var = mean_age.var()

    # Median Fill
    median_age = train_test['Age'].fillna(train_test['Age'].median())
    median_var = median_age.var()

    # Random Fill
    random_age = train_test['Age'].copy()

    random_values = train_test['Age'].dropna().sample(
        train_test['Age'].isnull().sum(),
        replace=True,
        random_state=42
    )

    random_age[random_age.isnull()] = random_values.values
    random_var = random_age.var()

    # Visualization
    fig, axes = plt.subplots(1, 3, figsize=(18,5))

    sns.histplot(mean_age, kde=True, ax=axes[0])
    axes[0].set_title(f"Mean Fill\nVariance = {mean_var:.2f}")

    sns.histplot(median_age, kde=True, ax=axes[1])
    axes[1].set_title(f"Median Fill\nVariance = {median_var:.2f}")

    sns.histplot(random_age, kde=True, ax=axes[2])
    axes[2].set_title(f"Random Fill\nVariance = {random_var:.2f}")

    plt.tight_layout()
    plt.show()

    print("Original Variance :", round(original_var,2))
    print("Mean Fill Variance :", round(mean_var,2))
    print("Median Fill Variance :", round(median_var,2))
    print("Random Fill Variance :", round(random_var,2))

# %%
compare_age_fill_visualization(train_test)
# Out:
# Original Variance : 207.75
# Mean Fill Variance : 165.98
# Median Fill Variance : 166.55
# Random Fill Variance : 204.88

# %%
# Age Missing Value Imputation Comparison
#Mean imputation reduced data variance and made the distribution smoother.
#Median imputation handled skewness better than mean imputation.
#Random value imputation preserved the original distribution more effectively.
#Random imputation is generally preferred for maintaining dataset variability.

# %%
bins=[0,2,12,19,30,60,100]
labels= ['Infans','Children','Teens','Young Adults','Adults','seniors']
train_test['Age_Group']=pd.cut(train_test['Age'],bins=bins,labels=labels,right=True)
train_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize FamilyType  \
# 0      0         A/5 21171   7.2500   NaN        S           2     Double
# 1      0          PC 17599  71.2833   C85        C           2     Double
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1      Alone
# ...

# %%
new_train_test = train_test.copy()
new_train_test
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
new_train_test.loc[
    new_train_test['Age'].isnull(),
    'Age'
] = new_train_test['Age'].dropna().sample(
    new_train_test['Age'].isnull().sum(),
    random_state=42
).values

# %%
new_train_test
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
new_train_test
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
Embarked_Mode = new_train_test['Embarked'].mode()[0]

# %%
Embarked_Mode
# Out:
# 'S'

# %%
new_train_test.loc[
    new_train_test['Embarked'].isnull(),
    'Embarked'
] = new_train_test['Embarked'].dropna().sample(
    new_train_test['Embarked'].isnull().sum(),
    random_state=42
).values

# %%
new_train_test
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
new_train_test['Fare'] = new_train_test['Fare'].fillna(
    new_train_test['Fare'].median()
)

# %%
new_train_test
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
new_train_test['FarePerPerson'] = new_train_test['FarePerPerson'].fillna(
    new_train_test['FarePerPerson'].median()
)

# %%
new_train_test
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
new_train_test['Age'].isnull().sum()
# Out:
# 0

# %%
new_train_test['Survived'].isnull().sum()
# Out:
# 418

# %%
new_train_test['Embarked'].isnull().sum()
# Out:
# 0

# %%
new_train_test['Fare'].isnull().sum()
# Out:
# 0

# %%
new_train_test['FarePerPerson'].isnull().sum()
# Out:
# 0

# %%
bins=[0,2,12,19,30,60,100]
labels= ['Infans','Children','Teens','Young Adults','Adults','seniors']
new_train_test['Age_Group']=pd.cut(new_train_test['Age'],bins=bins,labels=labels,right=True)
new_train_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize FamilyType  \
# 0      0         A/5 21171   7.2500   NaN        S           2     Double
# 1      0          PC 17599  71.2833   C85        C           2     Double
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1      Alone
# ...

# %%
new_train_test['Age_Group'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1309 entries, 0 to 1308
# Series name: Age_Group
# Non-Null Count  Dtype
# --------------  -----
# 1309 non-null   category
# dtypes: category(1)
# memory usage: 1.6 KB

# %%
sns.boxplot(x=train_test['Fare'])

plt.title("Fare Outliers")
plt.show()

# %%
# Fare Outliers (Before Treatment)
#The Fare column contained significant outliers.
#Some passengers paid extremely high ticket fares.
#The distribution was heavily right-skewed.

# %%
def handle_outliers_clip(new_train_test, col):

    nums = new_train_test[col].dropna().tolist()

    if len(nums) < 4:
        print(f"Not enough data points in {col} to calculate quartiles.")
        return new_train_test

    length = len(nums)
    order = sorted(nums)

    # Quartiles Position
    Q1 = (25 * (length + 1)) / 100
    Q2 = (50 * (length + 1)) / 100
    Q3 = (75 * (length + 1)) / 100

    def calculate_quartile(Q):

        if Q != int(Q):
            lower_index = int(Q) - 1
            upper_index = lower_index + 1

            # Safety Check
            if upper_index >= len(order):
                return order[-1]

            fraction = Q - int(Q)

            lower_value = order[lower_index]
            upper_value = order[upper_index]

            return lower_value + (fraction * (upper_value - lower_value))

        else:
            return order[int(Q) - 1]

    # Calculate Quartiles
    q1 = calculate_quartile(Q1)
    q2 = calculate_quartile(Q2)
    q3 = calculate_quartile(Q3)

    # IQR
    iqr = q3 - q1

    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)

    # Outliers Before Clipping
    outliers_before = new_train_test[
        (new_train_test[col] < lower_bound) |
        (new_train_test[col] > upper_bound)
    ][col]

    print("=" * 50)
    print(f"Column : {col}")
    print(f"Q1           : {q1:.2f}")
    print(f"Median (Q2)  : {q2:.2f}")
    print(f"Q3           : {q3:.2f}")
    print(f"IQR          : {iqr:.2f}")
    print(f"Lower Bound  : {lower_bound:.2f}")
    print(f"Upper Bound  : {upper_bound:.2f}")
    print(f"Outliers Before : {len(outliers_before)}")

    # Clip Outliers
    new_train_test[col] = new_train_test[col].clip(
        lower=lower_bound,
        upper=upper_bound
    )

    # Outliers After Clipping
    outliers_after = new_train_test[
        (new_train_test[col] < lower_bound) |
        (new_train_test[col] > upper_bound)
    ][col]

    print(f"Outliers After  : {len(outliers_after)}")
    print("=" * 50)

    return new_train_test

# %%
handle_outliers_clip(new_train_test,'Fare').head()
# Out:
# ...
# Column : Fare
# Q1           : 7.90
# Median (Q2)  : 14.45
# Q3           : 31.27
# IQR          : 23.38
# Lower Bound  : -27.17
# Upper Bound  : 66.34
# Outliers Before : 0
# Outliers After  : 0
# ...
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize FamilyType  \
# ...

# %%
sns.boxplot(x=new_train_test['Fare'])
plt.title("Fare Outliers")
plt.show()

# %%
# Fare Outliers (After Treatment)
#Outlier handling reduced the spread of extreme fare values.
#The distribution became more balanced and suitable for modeling.
#Data quality improved after treatment.

# %% [markdown]
# # Overall Conclusion

# %%
#The dataset analysis reveals that gender, passenger class, age, and family structure were the most important factors influencing survival.

#Key findings include:

#Females had significantly higher survival rates than males.
#1st class passengers were more likely to survive than 3rd class passengers.
#Children and small families had better chances of survival.
#Large families and lower-class passengers faced greater difficulty during evacuation.
#Missing value handling and outlier treatment improved the dataset quality for further machine learning tasks.
